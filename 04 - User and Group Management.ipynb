# %% [markdown]
# # User Account/Group Management
#
#
# ## Windows
#
# - Guests
#
# - Users can creat groups but only manage what they create (Standard)
# - Only Administrators can create users
#
#
# net localgroup user /add
#
# net group operators joe /add
#
# #### User Account Control
#
# Notifies user when changes are made to the computer
#
# Local Security Policy
#
#
#
# # AUTOMATE!
#
# ## Linux
#
#
# #### Users
#
# - Managed
# - Should not be put in a situation where it could be destructive
# - Treat them like teenagers
# - Naive
#
# ##### User Accounts
#
# Local User Accounts
# - Name
# - Password (encrypted)
#     - long length = strongest
#     - Special Characters
#     - Uppercase/Lowercase
#     - Unique of password
#     - Recycling Password
#     - Password Uniqness
#     -
#
# - Directory
# - Authenticate - are you who you say you are
# - Authorization - what you are you allowed to access
# - All processes must have a user.
#
#
#
#
# #### Groups
#
# - Accept / Reject (Low Level)
#
# - Set permissions
#
# - Role
# - Organizational
# - User
# - Resource
